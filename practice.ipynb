# %%
import re

re.findall('Okay', txt)
# Out:
# ['Okay']

# %%
txt = '''450
 00:17:53,457 --> 00:17:56,175
 Okay, but, um,
 thanks for being with us.

451
 00:17:56,175 --> 00:17:58,616
 But, um, if there's any
 college kids watching,

452
 00:17:58,616 --> 00:18:01,610
 But, um, but, um, but, um,
 but, um, but, um,

453
 00:18:01,610 --> 00:18:03,656
 We have to drink, professor.
454
 00:18:03,656 --> 00:18:07,507
 It's the rules.
 She said "But, um"

455
 00:18:09,788 --> 00:18:12,515
 But, um, but, um, but, um...
 god help us all.
 '''

# %%
len(re.findall('[B,b]ut, um', txt))
len(re.findall('4[0-9][0-9]', txt))
# Out:
# 7

# %%
txtsplit = re.split(r'[\s\n]', txt)
print(txtsplit)

for element in txtsplit: 
    print(element)
    if re.search(r'454', element):
        print('found a match!')
    else: 
        print('no match')
# Out:
# ['450', '', '00:17:53,457', '-->', '00:17:56,175', '', 'Okay,', 'but,', 'um,', '', 'thanks', 'for', 'being', 'with', 'us.', '', '451', '', '00:17:56,175', '-->', '00:17:58,616', '', 'But,', 'um,', 'if', "there's", 'any', '', 'college', 'kids', 'watching,', '', '452', '', '00:17:58,616', '-->', '00:18:01,610', '', 'But,', 'um,', 'but,', 'um,', 'but,', 'um,', '', 'but,', 'um,', 'but,', 'um,', '', '453', '', '00:18:01,610', '-->', '00:18:03,656', '', 'We', 'have', 'to', 'drink,', 'professor.', '454', '', '00:18:03,656', '-->', '00:18:07,507', '', "It's", 'the', 'rules.', '', 'She', 'said', '"But,', 'um"', '', '455', '', '00:18:09,788', '-->', '00:18:12,515', '', 'But,', 'um,', 'but,', 'um,', 'but,', 'um...', '', 'god', 'help', 'us', 'all.', '', '']
# 450
# no match
#
# no match
# 00:17:53,457
# no match
# -->
# no match
# 00:17:56,175
# no match
#
# no match
# Okay,
# no match
# but,
# no match
# um,
# no match
#
# no match
# thanks
# no match
# for
# no match
# being
# no match
# with
# no match
# us.
# no match
#
# no match
# 451
# no match
#
# no match
# 00:17:56,175
# no match
# -->
# no match
# 00:17:58,616
# no match
#
# no match
# But,
# no match
# um,
# no match
# if
# no match
# there's
# no match
# any
# no match
#
# no match
# college
# no match
# kids
# no match
# watching,
# no match
#
# no match
# 452
# no match
#
# no match
# 00:17:58,616
# no match
# -->
# no match
# 00:18:01,610
# no match
#
# no match
# But,
# no match
# um,
# no match
# but,
# no match
# um,
# no match
# but,
# no match
# um,
# no match
#
# no match
# but,
# no match
# um,
# no match
# but,
# no match
# um,
# no match
#
# no match
# 453
# no match
#
# no match
# 00:18:01,610
# no match
# -->
# no match
# 00:18:03,656
# no match
#
# no match
# We
# no match
# have
# no match
# to
# no match
# drink,
# no match
# professor.
# no match
# 454
# found a match!
#
# no match
# 00:18:03,656
# no match
# -->
# no match
# 00:18:07,507
# no match
#
# no match
# It's
# no match
# the
# no match
# rules.
# no match
#
# no match
# She
# no match
# said
# no match
# "But,
# no match
# um"
# no match
#
# no match
# 455
# no match
#
# no match
# 00:18:09,788
# no match
# -->
# no match
# 00:18:12,515
# no match
#
# no match
# But,
# no match
# um,
# no match
# but,
# no match
# um,
# no match
# but,
# no match
# um...
# no match
#
# no match
# god
# no match
# help
# no match
# us
# no match
# all.
# no match
#
# no match
#
# no match
